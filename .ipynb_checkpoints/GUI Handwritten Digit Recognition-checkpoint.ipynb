# %%
import gradio as gr
import tensorflow as tf
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import gradio as gr
#       2 import tensorflow as tf
#       3 from matplotlib import pyplot as plt
#
# File ~\anaconda3\lib\site-packages\gradio\__init__.py:3
#       1 import pkgutil
# ----> 3 import gradio.components as components
#       4 import gradio.inputs as inputs
#       5 import gradio.outputs as outputs
#
# File ~\anaconda3\lib\site-packages\gradio\components\__init__.py:1
# ----> 1 from gradio.components.annotated_image import AnnotatedImage
#       2 from gradio.components.audio import Audio
#       3 from gradio.components.bar_plot import BarPlot
#
# File ~\anaconda3\lib\site-packages\gradio\components\annotated_image.py:13
#      10 from PIL import Image as _Image  # using _ to minimize namespace pollution
#      12 from gradio import utils
# ...
